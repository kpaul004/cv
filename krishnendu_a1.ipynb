# %% [markdown]
# <a href="https://colab.research.google.com/github/kpaul004/cv/blob/master/krishnendu_a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pf=pd.read_csv("pokemon.csv")
print(pf)
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pf.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# against_bug                1.0
# against_dark               1.0
# against_dragon             1.0
# against_electric           1.0
# against_fairy              1.0
# against_fight              1.0
# against_fire               1.0
# against_flying             1.0
# against_ghost              1.0
# against_grass              1.0
# against_ground             1.0
# against_ice                1.0
# against_normal             1.0
# against_poison             1.0
# against_psychic            1.0
# against_rock               1.0
# against_steel              1.0
# against_water              1.0
# attack                    75.0
# base_egg_steps          5120.0
# ...

# %%
pf.set_index("abilities")
# Out:
#                              against_bug  against_dark  against_dragon  \
# abilities
# ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# ['Blaze', 'Solar Power']            0.50           1.0             1.0
# ['Blaze', 'Solar Power']            0.50           1.0             1.0
# ...                                  ...           ...             ...
# ['Beast Boost']                     0.25           1.0             0.5
# ['Beast Boost']                     1.00           1.0             0.5
# ['Beast Boost']                     2.00           0.5             2.0
# ['Prism Armor']                     2.00           2.0             1.0
# ['Soul-Heart']                      0.25           0.5             0.0
#
#                              against_electric  against_fairy  against_fight  \
# abilities
# ...

# %%
print(pf)
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pf.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# against_bug          9.962547e-01
# against_dark         1.057116e+00
# against_dragon       9.687890e-01
# against_electric     1.073970e+00
# against_fairy        1.068976e+00
# against_fight        1.065543e+00
# against_fire         1.135456e+00
# against_flying       1.192884e+00
# against_ghost        9.850187e-01
# against_grass        1.034020e+00
# against_ground       1.098002e+00
# against_ice          1.208177e+00
# against_normal       8.870162e-01
# against_poison       9.753433e-01
# against_psychic      1.005306e+00
# against_rock         1.250312e+00
# against_steel        9.834582e-01
# against_water        1.058365e+00
# ...

# %%
pf.head(6)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
# ...

# %%
pf.tail(6)
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 795  ['Beast Boost']         1.00           1.0             1.0
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 795               0.5            1.0            1.0           1.0
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
# ...

# %%
pf.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...
